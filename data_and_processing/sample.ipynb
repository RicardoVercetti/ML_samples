# %%
# creating my own data set
# importing libraries
from sklearn.datasets import make_blobs

# matplotlib for plotting
from matplotlib import pyplot as plt 
from matplotlib import style

# %%
# make blobs dataset
style.use("fivethirtyeight")
 
X, y = make_blobs(n_samples = 100, centers = 3, 
               cluster_std = 1, n_features = 2)
 
plt.scatter(X[:, 0], X[:, 1], s = 40, color = 'g')
plt.xlabel("X")
plt.ylabel("Y")
 
plt.show()
plt.clf()

# %%
# print(type(X))
print(y.shape)
print(X.shape)
# print(dir(X))
# print(X.all())
print(y[:5])
print(X[:5])
# Out:
# (100,)
# (100, 2)
# [0 2 0 1 0]
# [[2.78076217 6.29313367]
#  [4.29374307 9.33798503]
#  [4.21762374 5.49763452]
#  [0.29949724 4.17777549]
#  [2.8770481  4.56196702]]

# %%
for i in range(len(X)):
    if y[i] == 1:
        print("X :",X[i])
